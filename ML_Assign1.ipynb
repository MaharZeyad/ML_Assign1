# %%
#reading the first dataset
import pandas as pd

dataset = pd.read_csv('healthcare_dataset.csv')
dataset.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
#number of features
len(dataset.columns)
# Out:
# 15

# %%
#blood types
dataset['Blood Type'].unique()
# Out:
# array(['B-', 'A+', 'A-', 'O+', 'AB+', 'AB-', 'B+', 'O-'], dtype=object)

# %%
#most frequent blood type
dataset['Blood Type'].mode() #or: dataset['Blood Type'].value_counts().idxmax()
# Out:
# 0    A-
# Name: Blood Type, dtype: object

# %%
#rarest blood type
dataset['Blood Type'].value_counts().idxmin()
# Out:
# 'O-'

# %%
#medical conditions
len(dataset['Medical Condition'].unique())
# Out:
# 6

# %%
#youngest patient
youngest = dataset[dataset['Age'] == dataset['Age'].min()]
print('The name of the youngest patient is: ', youngest['Name'].iloc[0],
      '\nand his age is ', dataset['Age'].min())
# Out:
# The name of the youngest patient is:  jamES BasS phD
# and his age is  13

# %%
#oldest patient
youngest = dataset[dataset['Age'] == dataset['Age'].max()]
print('The name of the oldest patient is: ', youngest['Name'].iloc[0],
      '\nand his age is ', dataset['Age'].max())
# Out:
# The name of the oldest patient is:  DAVId NeWTOn
# and his age is  89

# %%
#average billing amount
dataset['Billing Amount'].mean()
# Out:
# 25539.316097211795

# %%
#total billing amount across all patients
dataset['Billing Amount'].sum()
# Out:
# 1417432043.3952546

# %%
#reading the second dataset
import pandas as pd

dataset2 = pd.read_csv('Salaries.csv')
dataset2.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
#columns between the 2nd and 8th columns, and rows from 1 to 1000
dataset2.iloc[1:1001, 1:9] #note: I included the 2nd and 8th cloumns(from column 2 to 8)
# Out:
#              EmployeeName                                      JobTitle  \
# 1            GARY JIMENEZ               CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI               CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG          WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER  DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5          DAVID SULLIVAN                     ASSISTANT DEPUTY CHIEF II
# ...                   ...                                           ...
# 996         KATHERINE MAH                     CLINICAL NURSE SPECIALIST
# 997   CHRISTINE DAVENPORT                     CLINICAL NURSE SPECIALIST
# 998           ANNE HUGHES                     CLINICAL NURSE SPECIALIST
# 999            JOHN FAZIO                     CLINICAL NURSE SPECIALIST
# 1000         ROBERT KUZMA         CAPTAIN, EMERGENCYCY MEDICAL SERVICES
#
#         BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits
# 1     155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2     212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3      77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4     134401.60      9737.00  182234.59       NaN  326373.19         326373.19
# 5     118602.00      8601.00  189082.74       NaN  316285.74         316285.74
# ...         ...          ...        ...       ...        ...               ...
# 996   169572.06         0.00     250.00       NaN  169822.06         169822.06
# 997   169572.05         0.00     250.00       NaN  169822.05         169822.05
# 998   169572.01         0.00     250.00       NaN  169822.01         169822.01
# 999   169572.00         0.00     250.00       NaN  169822.00         169822.00
# 1000  140546.84      8577.69   20692.86       NaN  169817.39         169817.39
#
# [1000 rows x 8 columns]

# %%
#number of missing values for each feature
dataset2.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
#total count of the missing values in the dataset
dataset2.isnull().sum().sum()
# Out:
# 334088

# %%
#median value for the "basepay" feature
dataset2['BasePay'].median()
# Out:
# 65007.45
